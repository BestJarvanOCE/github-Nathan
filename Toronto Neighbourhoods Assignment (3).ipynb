# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing pandas and reading the data file turned from a wikipedia page to a csv.

# %%
df = pd.read_csv('/resources/data/Neighbourhoods_in_Toronto.csv')
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# Dropping rows that have "Not Assigned" as boroughs

# %%
df = df[df.Borough != 'Not assigned']
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M6A        North York  Lawrence Heights
# 6      M6A        North York    Lawrence Manor

# %% [markdown]
# Combining neighbourhoods that share the same boroughs.

# %%
df = df.groupby(['Postcode','Borough'], sort=False).agg(', '.join)
df.reset_index(inplace=True)
df
# Out:
#     Postcode           Borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M7A  Downtown Toronto
# ..       ...               ...
# 98       M8X         Etobicoke
# 99       M4Y  Downtown Toronto
# 100      M7Y      East Toronto
# 101      M8Y         Etobicoke
# 102      M8Z         Etobicoke
#
#                                          Neighbourhood
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                     Lawrence Heights, Lawrence Manor
# 4                                         Queen's Park
# ..                                                 ...
# 98       The Kingsway, Montgomery Road, Old Mill North
# 99                                Church and Wellesley
# 100  Business Reply Mail Processing Centre 969 Eastern
# ...

# %% [markdown]
# Boroughs with no assigned neighbourhood name are granted its borough's name.

# %%
df['Neighbourhood']=np.where(
    df['Neighbourhood'] == 'Not assigned',
    df['Borough'], df['Neighbourhood'])
df.head(12)
# Out:
#    Postcode           Borough  \
# 0       M3A        North York
# 1       M4A        North York
# 2       M5A  Downtown Toronto
# 3       M6A        North York
# 4       M7A  Downtown Toronto
# 5       M9A      Queen's Park
# 6       M1B       Scarborough
# 7       M3B        North York
# 8       M4B         East York
# 9       M5B  Downtown Toronto
# 10      M6B        North York
# 11      M9B         Etobicoke
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                                        Harbourfront
# 3                    Lawrence Heights, Lawrence Manor
# 4                                        Queen's Park
# 5                                        Queen's Park
# 6                                      Rouge, Malvern
# 7                                     Don Mills North
# 8                     Woodbine Gardens, Parkview Hill
# ...

# %% [markdown]
# The dataframe's number of rows and columns respectively.

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# Installing and importing geocoder, with reading the data as PC_Loc (Post Code Location)

# %%
 pip install geocoder
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geocoder

# %%
PC_Loc = pd.read_csv('http://cocl.us/Geospatial_data')
PC_Loc.head(10)
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476
# 5         M1J  43.744734 -79.239476
# 6         M1K  43.727929 -79.262029
# 7         M1L  43.711112 -79.284577
# 8         M1M  43.716316 -79.239476
# 9         M1N  43.692657 -79.264848

# %% [markdown]
# Changing the column name Postal Code to Postcode for diction's sake.

# %%
PC_Loc.rename(columns={'Postal Code':'Postcode'}, inplace = True)
PC_Loc.head(10)
# Out:
#   Postcode   Latitude  Longitude
# 0      M1B  43.806686 -79.194353
# 1      M1C  43.784535 -79.160497
# 2      M1E  43.763573 -79.188711
# 3      M1G  43.770992 -79.216917
# 4      M1H  43.773136 -79.239476
# 5      M1J  43.744734 -79.239476
# 6      M1K  43.727929 -79.262029
# 7      M1L  43.711112 -79.284577
# 8      M1M  43.716316 -79.239476
# 9      M1N  43.692657 -79.264848

# %% [markdown]
# Merging the two tables together by the similar variable 'Postcode'

# %%
df_loc = pd.merge(PC_Loc, df, on = 'Postcode')
df_loc.head(10)
# Out:
#   Postcode   Latitude  Longitude      Borough  \
# 0      M1B  43.806686 -79.194353  Scarborough
# 1      M1C  43.784535 -79.160497  Scarborough
# 2      M1E  43.763573 -79.188711  Scarborough
# 3      M1G  43.770992 -79.216917  Scarborough
# 4      M1H  43.773136 -79.239476  Scarborough
# 5      M1J  43.744734 -79.239476  Scarborough
# 6      M1K  43.727929 -79.262029  Scarborough
# 7      M1L  43.711112 -79.284577  Scarborough
# 8      M1M  43.716316 -79.239476  Scarborough
# 9      M1N  43.692657 -79.264848  Scarborough
#
#                                      Neighbourhood
# 0                                   Rouge, Malvern
# 1           Highland Creek, Rouge Hill, Port Union
# 2                Guildwood, Morningside, West Hill
# 3                                           Woburn
# 4                                        Cedarbrae
# 5                              Scarborough Village
# 6      East Birchmount Park, Ionview, Kennedy Park
# ...

# %% [markdown]
# The new table (df_loc_tor) used for plotting has its data points with boroughs within Toronto.

# %%
df_loc_tor = df_loc[df_loc['Borough'].str.contains('Toronto',regex=False)]
df_loc_tor.head(10)
# Out:
#    Postcode   Latitude  Longitude          Borough  \
# 37      M4E  43.676357 -79.293031     East Toronto
# 41      M4K  43.679557 -79.352188     East Toronto
# 42      M4L  43.668999 -79.315572     East Toronto
# 43      M4M  43.659526 -79.340923     East Toronto
# 44      M4N  43.728020 -79.388790  Central Toronto
# 45      M4P  43.712751 -79.390197  Central Toronto
# 46      M4R  43.715383 -79.405678  Central Toronto
# 47      M4S  43.704324 -79.388790  Central Toronto
# 48      M4T  43.689574 -79.383160  Central Toronto
# 49      M4V  43.686412 -79.400049  Central Toronto
#
#                                         Neighbourhood
# 37                                        The Beaches
# 41                       The Danforth West, Riverdale
# 42                     The Beaches West, India Bazaar
# 43                                    Studio District
# 44                                      Lawrence Park
# 45                                   Davisville North
# ...

# %% [markdown]
# Creation of folium map

# %%
import folium

# %%
Toronto_map = folium.Map(location=[43.651,-79.347],zoom_start=12)
for lat,lng,borough,neighbourhood in zip(df_loc_tor['Latitude'],df_loc_tor['Longitude'],df_loc_tor['Borough'],df_loc_tor['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=6,
    popup=label,
    color='red',
    fill=True,
    fill_color='#db4242',
    fill_opacity=0.8,
    parse_html=False).add_to(Toronto_map)
Toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
